# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# -- 第一次執行時，使用 git clone --
# 為了 clone 私有 repo，我們需要使用 Personal Access Token (PAT)
# 格式: https://<你的PAT>@github.com/<你的使用者名稱>/<你的repo名稱>.git

# 請替換成你自己的 PAT 和 repo 網址
# !git clone https://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@github.com/Candibulldog/CVPDL-2025-HW1-Object-Detection.git

# -- 未來更新程式碼時，進入資料夾後用 git pull 即可 --
# %cd CVPDL-2025-HW1-Object-Detection
# !git pull
# Out:
# Cloning into 'CVPDL-2025-HW1-Object-Detection'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 4 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (4/4), done.
